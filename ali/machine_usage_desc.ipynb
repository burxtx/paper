# %%
import numpy as np
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt
import seaborn as sns
import dask.dataframe as dd

# %matplotlib inline

# %% [markdown]
# Read files:

# %%
machine_usage_data_path = 'data/machine_usage.tar.gz'
mu_headers=['machine_id', 'time_stamp', 'cpu_util_percent', 'mem_util_percent', 'mem_gps', 'mpki', 'net_in', 'net_out', 'disk_io_percent']
chunk_size = 10**6
#  dfs = []
# with pd.read_csv(machine_usage_data_path, chunksize=chunk_size, iterator=True) as reader:
#     for chunk in reader:
#         df = pd.DataFrame(chunk)
#         dfs.append(df)
# machine_usage_dataframe = pd.concat(dfs)
machine_usage_data_frame = dd.read_csv(machine_usage_data_path)
# Out:
# /home/tianxi/work/paper/playground/lib/python3.11/site-packages/dask/dataframe/io/csv.py:544: UserWarning: Warning gzip compression does not support breaking apart files
# Please ensure that each individual file can fit in memory and
# use the keyword ``blocksize=None to remove this message``
# Setting ``blocksize=None``
#   warn(
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/work/paper/playground/lib/python3.11/site-packages/dask/backends.py:136, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     135 try:
# --> 136     return func(*args, **kwargs)
#     137 except Exception as e:
#
# File ~/work/paper/playground/lib/python3.11/site-packages/dask/dataframe/io/csv.py:761, in make_reader.<locals>.read(urlpath, blocksize, lineterminator, compression, sample, sample_rows, enforce, assume_missing, storage_options, include_path_column, **kwargs)
#     748 def read(
#     749     urlpath,
#     750     blocksize="default",
#    (...)
#     759     **kwargs,
#     760 ):
# --> 761     return read_pandas(
#     762         reader,
#     763         urlpath,
#     764         blocksize=blocksize,
#     765         lineterminator=lineterminator,
#     766         compression=compression,
#     767         sample=sample,
#     768         sample_rows=sample_rows,
#     769         enforce=enforce,
#     770         assume_missing=assume_missing,
#     771         storage_options=storage_options,
#     772         include_path_column=include_path_column,
#     773         **kwargs,
#     774     )
#
# File ~/work/paper/playground/lib/python3.11/site-packages/dask/dataframe/io/csv.py:630, in read_pandas(reader, urlpath, blocksize, lineterminator, compression, sample, sample_rows, enforce, assume_missing, storage_options, include_path_column, **kwargs)
#     629 try:
# --> 630     head = reader(BytesIO(b_sample), nrows=sample_rows, **head_kwargs)
#     631 except pd.errors.ParserError as e:
#
# File ~/work/paper/playground/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/work/paper/playground/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#
# File ~/work/paper/playground/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/work/paper/playground/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1679, in TextFileReader._make_engine(self, f, engine)
#    1678 try:
# -> 1679     return mapping[engine](f, **self.options)
#    1680 except Exception:
#
# File ~/work/paper/playground/lib/python3.11/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#
# File ~/work/paper/playground/lib/python3.11/site-packages/pandas/_libs/parsers.pyx:550, in pandas._libs.parsers.TextReader.__cinit__()
#
# File ~/work/paper/playground/lib/python3.11/site-packages/pandas/_libs/parsers.pyx:639, in pandas._libs.parsers.TextReader._get_header()
#
# File ~/work/paper/playground/lib/python3.11/site-packages/pandas/_libs/parsers.pyx:850, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/work/paper/playground/lib/python3.11/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File ~/work/paper/playground/lib/python3.11/site-packages/pandas/_libs/parsers.pyx:2021, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 124: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       3 chunk_size = 10**6
#       4 # with pd.read_csv(machine_usage_data_path, chunksize=chunk_size, iterator=True) as reader:
#       5 #     for chunk in reader:
#       6 #         df = pd.DataFrame(chunk)
#       7 #         dfs.append(df)
#       8 # machine_usage_dataframe = pd.concat(dfs)
# ----> 9 machine_usage_data_frame = dd.read_csv(machine_usage_data_path)
#
# File ~/work/paper/playground/lib/python3.11/site-packages/dask/backends.py:138, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     136     return func(*args, **kwargs)
#     137 except Exception as e:
# --> 138     raise type(e)(
#     139         f"An error occurred while calling the {funcname(func)} "
#     140         f"method registered to the {self.backend} backend.\n"
#     141         f"Original Message: {e}"
#     142     ) from e
#
# TypeError: function takes exactly 5 arguments (1 given)

# %%
machine_meta_dataframe.head(20)
# Out:
#           machine_id  time_stamp  failure_domain_1  failure_domain_2  cpu_num  \
# 0   machine_meta.csv         0.0             219.0              17.0     96.0
# 1                m_1    148984.0             219.0              17.0     96.0
# 2                m_1    535156.0             219.0              17.0     96.0
# 3                m_1    552384.0             219.0              17.0     96.0
# 4                m_1    658423.0             219.0              17.0     96.0
# 5                m_1    664518.0             219.0              17.0     96.0
# 6                m_1    681229.0             219.0              17.0     96.0
# 7                m_1    683653.0             219.0              17.0     96.0
# 8               m_10         0.0             128.0              17.0     96.0
# 9               m_10    570024.0             128.0              17.0     96.0
# 10              m_10    573570.0             128.0              17.0     96.0
# 11             m_100         0.0               9.0               9.0     96.0
# 12             m_100    612226.0               9.0               9.0     96.0
# 13             m_100    615987.0               9.0               9.0     96.0
# 14             m_100    641294.0               9.0               9.0     96.0
# 15            m_1000         0.0              89.0              16.0     96.0
# 16            m_1000    599230.0              89.0              16.0     96.0
# 17            m_1000    608335.0              89.0              16.0     96.0
# 18            m_1001         0.0              92.0              19.0     96.0
# 19            m_1001    571333.0              92.0              19.0     96.0
#
#     mem_size status
# 0      100.0  USING
# 1      100.0  USING
# 2      100.0  USING
# 3      100.0  USING
# 4      100.0  USING
# 5      100.0  USING
# 6      100.0  USING
# 7      100.0  USING
# 8      100.0  USING
# 9      100.0  USING
# 10     100.0  USING
# 11     100.0  USING
# 12     100.0  USING
# 13     100.0  USING
# 14     100.0  USING
# 15     100.0  USING
# 16     100.0  USING
# 17     100.0  USING
# 18     100.0  USING
# 19     100.0  USING

# %%
machine_meta_dataframe['status'].value_counts()
# Out:
# Running cells with 'playground' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/home/tianxi/work/paper/playground/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
machine_meta_dataframe.sort_values(by="time_stamp")
# Out:
#              machine_id  time_stamp  failure_domain_1  failure_domain_2  \
# 0      machine_meta.csv         0.0             219.0              17.0
# 3989             m_1853         0.0              54.0               2.0
# 11417            m_3396         0.0              67.0              17.0
# 3985             m_1852         0.0               4.0               4.0
# 11418            m_3397         0.0             224.0              19.0
# ...                 ...         ...               ...               ...
# 13068            m_3724    696608.0              70.0              18.0
# 10072            m_3104    696608.0             246.0               6.0
# 5449             m_2142    696632.0             194.0              19.0
# 4121             m_1879    696633.0             115.0              13.0
# 17592               NaN         NaN               NaN               NaN
#
#        cpu_num  mem_size status
# 0         96.0     100.0  USING
# 3989      96.0     100.0  USING
# 11417     96.0     100.0  USING
# 3985      96.0     100.0  USING
# 11418     96.0     100.0  USING
# ...        ...       ...    ...
# 13068     96.0     100.0  USING
# 10072     96.0     100.0  USING
# 5449      96.0     100.0  USING
# 4121      96.0     100.0  USING
# 17592      NaN       NaN    NaN
#
# [17593 rows x 7 columns]

# %%
machine_usage_data_frame.head(20)
# Out:
#    machine_id  time_stamp  cpu_util_percent  mem_util_percent  mem_gps  mpki  \
# 0      m_1932      386640                41                92      NaN   NaN
# 1      m_1932      386670                43                92      NaN   NaN
# 2      m_1932      386690                44                92      NaN   NaN
# 3      m_1932      386800                46                92      NaN   NaN
# 4      m_1932      386930                44                93      NaN   NaN
# 5      m_1932      387000                41                93      NaN   NaN
# 6      m_1932      387090                46                93      NaN   NaN
# 7      m_1932      387170                47                93      NaN   NaN
# 8      m_1932      387180                46                93      NaN   NaN
# 9      m_1932      387200                46                93      NaN   NaN
# 10     m_1932      387530                46                93      NaN   NaN
# 11     m_1932      387610                73                97      NaN   NaN
# 12     m_1932      387690                75                97      NaN   NaN
# 13     m_1932      387840                68                96      NaN   NaN
# 14     m_1932      387900                71                96      NaN   NaN
# 15     m_1932      387950                68                96      NaN   NaN
# 16     m_1932      387990                66                96      NaN   NaN
# 17     m_1932      388050                55                96      NaN   NaN
# 18     m_1932      388160                52                97      NaN   NaN
# 19     m_1932      388170                53                96      NaN   NaN
#
#     net_in  net_out  disk_io_percent
# 0    43.04    33.08                5
# 1    43.04    33.08                5
# 2    43.05    33.08                5
# 3    43.05    33.08                3
# 4    43.05    33.09                4
# 5    43.05    33.09                4
# 6    43.05    33.09                3
# 7    43.05    33.09                4
# 8    43.05    33.09                3
# 9    43.05    33.09                3
# 10   43.06    33.10                5
# 11   43.06    33.10                7
# 12   43.06    33.10                5
# 13   43.07    33.10                3
# 14   43.07    33.10                5
# 15   43.07    33.10                5
# 16   43.07    33.10                4
# 17   43.07    33.11                2
# 18   43.07    33.11                5
# 19   43.07    33.11                5
