# %%
from pathlib import Path

import numpy as np
import pandas as pd
import dask.dataframe as dd
from IPython.display import display
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
chunk_size = 10**6

# %%
# read batch_task table

# with pd.read_csv(batch_task_data_path, chunksize=chunk_size, iterator=True) as reader:
#     for chunk in reader:
#         df = pd.DataFrame(chunk)
#         dfs.append(df)
# batch_task_dataframe = pd.concat(dfs)
batch_task_data_path = 'data/batch_task.csv'
bt_headers=['task_name','instance_num', 'job_name', 'task_type', 'status', 'start_time', 'end_time', 'plan_cpu', 'plan_mem']
dfs = []
with pd.read_csv(batch_task_data_path, 
    # dtype={
    #     'task_name': 'string',
    #     'instance_num': 'Int64',
    #     'job_name': 'string',
    #     'task_type': 'string',
    #     'status': 'string',
    #     'start_time': 'Int64',
    #     'end_time': 'Int64',
    #     'plan_cpu': 'float64',
    #     'plan_mem': 'float64'
    # },
    names=bt_headers, chunksize=chunk_size, iterator=True) as reader:
    for chunk in reader:
        df = pd.DataFrame(chunk)
        dfs.append(df)
batch_task_dataframe = pd.concat(dfs)

# %%
batch_task_dataframe.head(20)
# Out:
#    task_name  instance_num job_name  task_type      status  start_time  \
# 0         M1           1.0      j_1          1  Terminated      419912
# 1       R2_1           1.0      j_2          1  Terminated       87076
# 2         M1           1.0      j_2          1  Terminated       87076
# 3       R6_3         371.0      j_3          1  Terminated      157297
# 4     J4_2_3        1111.0      j_3          1  Terminated      157329
# 5       R2_1           1.0      j_3          1  Terminated      157322
# 6     J8_3_7        1111.0      j_3          1  Terminated      157331
# 7         M3       12846.0      j_3          1  Terminated      157213
# 8       R9_8           1.0      j_3          1  Terminated      157376
# 9       R1_3         371.0      j_3          1  Terminated      157297
# 10      R5_4           1.0      j_3          1  Terminated      157376
# 11      R7_6           1.0      j_3          1  Terminated      157326
# 12        M1           1.0      j_7          1  Terminated      299703
# 13      R2_1           1.0      j_7          1  Terminated      299707
# 14      R5_4           1.0      j_8          1  Terminated      316284
# 15        M6        1138.0      j_8          1  Terminated      316284
# 16    R16_15           1.0      j_8          1  Terminated      316284
# 17     R10_9           1.0      j_8          1  Terminated      316284
# 18        M1           1.0      j_8          1  Terminated      316284
# 19    R15_14           1.0      j_8          1  Terminated      316284
#
#     end_time  plan_cpu  plan_mem
# 0     419912     100.0      0.20
# 1      87086      50.0      0.20
# 2      87083      50.0      0.20
# 3     157325     100.0      0.49
# 4     157376     100.0      0.59
# 5     157328     100.0      0.39
# 6     157376     100.0      0.59
# 7     157295     100.0      0.30
# 8     157381     100.0      0.39
# 9     157322     100.0      0.49
# 10    157381     100.0      0.39
# 11    157330     100.0      0.39
# 12    299707     100.0      0.30
# 13    299710     100.0      0.39
# 14    316295      50.0      0.20
# 15    316297      50.0      0.20
# 16    316310      50.0      0.20
# 17    316294      50.0      0.20
# 18    316295      50.0      0.20
# 19    316310      50.0      0.20

# %%
batch_task_dataframe["status"].value_counts()
# Out:
# Terminated    14059143
# Running         129354
# Failed           83276
# Waiting          23958
# Name: status, dtype: int64

# %%
batch_task_dataframe["task_type"].value_counts()
# Out:
# 1     12207703
# 6      1226388
# 5       399489
# 10      322929
# 8        53933
# 3        35061
# 11       28777
# 12        8889
# 9         6543
# 4         5519
# 7          488
# 2           12
# Name: task_type, dtype: int64

# %% [markdown]
# 获取running和failed，即end_time为0的数据

# %%
rof = batch_task_dataframe[batch_task_dataframe["end_time"]==0]

# %%
rof.head()
# Out:
#                              task_name  instance_num job_name  task_type  \
# 102  task_MTM0ODUxMTY0NjQzMTI1NTc1MQ==           1.0     j_85          6
# 103  task_LTE4NjUxMjg5NDY5MDI4NjAzNzU=           1.0     j_85          6
# 277  task_LTE4NjUxMjg5NDY5MDI4NjAzNzU=           1.0    j_189          6
# 668  task_MTM0ODUxMTY0NjQzMTI1NTc1MQ==           NaN    j_585          6
# 670  task_LTE4NjUxMjg5NDY5MDI4NjAzNzU=           NaN    j_585          6
#
#       status  start_time  end_time  plan_cpu  plan_mem
# 102  Running      474800         0       NaN       NaN
# 103  Running      474800         0       NaN       NaN
# 277  Running      617172         0       NaN       NaN
# 668  Waiting           0         0       NaN       NaN
# 670  Waiting           0         0       NaN       NaN

# %%
df=batch_task_dataframe.sort_values(by='start_time',ascending=True)
a=df[df["task_name"]=="task_MTM0ODUxMTY0NjQzMTI1NTc1MQ=="]
a[a["start_time"]>0]
# Out:
#                                   task_name  instance_num   job_name  \
# 11174934  task_MTM0ODUxMTY0NjQzMTI1NTc1MQ==           1.0  j_1448450
# 12131124  task_MTM0ODUxMTY0NjQzMTI1NTc1MQ==           1.0  j_2293673
# 10219724  task_MTM0ODUxMTY0NjQzMTI1NTc1MQ==           1.0   j_600204
# 11782134  task_MTM0ODUxMTY0NjQzMTI1NTc1MQ==           1.0  j_1984370
# 13042148  task_MTM0ODUxMTY0NjQzMTI1NTc1MQ==           1.0  j_3095090
# ...                                     ...           ...        ...
# 6256368   task_MTM0ODUxMTY0NjQzMTI1NTc1MQ==          41.0  j_1298744
# 1799547   task_MTM0ODUxMTY0NjQzMTI1NTc1MQ==           1.0  j_1579468
# 4291092   task_MTM0ODUxMTY0NjQzMTI1NTc1MQ==           1.0  j_3771817
# 5647629   task_MTM0ODUxMTY0NjQzMTI1NTc1MQ==         689.0   j_758497
# 11552286  task_MTM0ODUxMTY0NjQzMTI1NTc1MQ==           3.0  j_1779683
#
#           task_type      status  start_time  end_time  plan_cpu  plan_mem
# 11174934          6  Terminated       85337     86127      30.0      0.05
# 12131124          6  Terminated       85540     86283      30.0      0.05
# 10219724          6  Terminated       85572     86316      30.0      0.05
# 11782134          6  Terminated       85595     86345      30.0      0.05
# 13042148          6  Terminated       85620     86196      30.0      0.05
# ...             ...         ...         ...       ...       ...       ...
# 6256368           6  Terminated      691191    691304      30.0      0.05
# 1799547           6  Terminated      691192    691275      30.0      0.05
# 4291092           6  Terminated      691193    691205      30.0      0.05
# 5647629           6  Terminated      691194    691304      30.0      0.05
# 11552286          6  Terminated      691204    691352      30.0      0.05
#
# [401417 rows x 9 columns]

# %%
a=rof[rof["status"]=="Failed"]
a.head()
# Out:
# Empty DataFrame
# Columns: [task_name, instance_num, job_name, task_type, status, start_time, end_time, plan_cpu, plan_mem]
# Index: []

# %%
batch_task_dataframe['lifetime'] = np.maximum((batch_task_dataframe['end_time'] - batch_task_dataframe['start_time']) ,300)/ 3600
batch_task_dataframe.head(20)
# Out:
#    task_name  instance_num job_name  task_type      status  start_time  \
# 0         M1           1.0      j_1          1  Terminated      419912
# 1       R2_1           1.0      j_2          1  Terminated       87076
# 2         M1           1.0      j_2          1  Terminated       87076
# 3       R6_3         371.0      j_3          1  Terminated      157297
# 4     J4_2_3        1111.0      j_3          1  Terminated      157329
# 5       R2_1           1.0      j_3          1  Terminated      157322
# 6     J8_3_7        1111.0      j_3          1  Terminated      157331
# 7         M3       12846.0      j_3          1  Terminated      157213
# 8       R9_8           1.0      j_3          1  Terminated      157376
# 9       R1_3         371.0      j_3          1  Terminated      157297
# 10      R5_4           1.0      j_3          1  Terminated      157376
# 11      R7_6           1.0      j_3          1  Terminated      157326
# 12        M1           1.0      j_7          1  Terminated      299703
# 13      R2_1           1.0      j_7          1  Terminated      299707
# 14      R5_4           1.0      j_8          1  Terminated      316284
# 15        M6        1138.0      j_8          1  Terminated      316284
# 16    R16_15           1.0      j_8          1  Terminated      316284
# 17     R10_9           1.0      j_8          1  Terminated      316284
# 18        M1           1.0      j_8          1  Terminated      316284
# 19    R15_14           1.0      j_8          1  Terminated      316284
#
#     end_time  plan_cpu  plan_mem  lifetime
# 0     419912     100.0      0.20  0.083333
# 1      87086      50.0      0.20  0.083333
# 2      87083      50.0      0.20  0.083333
# 3     157325     100.0      0.49  0.083333
# 4     157376     100.0      0.59  0.083333
# 5     157328     100.0      0.39  0.083333
# 6     157376     100.0      0.59  0.083333
# 7     157295     100.0      0.30  0.083333
# 8     157381     100.0      0.39  0.083333
# 9     157322     100.0      0.49  0.083333
# 10    157381     100.0      0.39  0.083333
# 11    157330     100.0      0.39  0.083333
# 12    299707     100.0      0.30  0.083333
# 13    299710     100.0      0.39  0.083333
# 14    316295      50.0      0.20  0.083333
# 15    316297      50.0      0.20  0.083333
# 16    316310      50.0      0.20  0.083333
# 17    316294      50.0      0.20  0.083333
# 18    316295      50.0      0.20  0.083333
# 19    316310      50.0      0.20  0.083333

# %%
batch_task_dataframe.describe()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\paper\ali\batch_desc.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/paper/ali/batch_desc.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> batch_task_dataframe.describe()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py:10227, in NDFrame.describe(self, percentiles, include, exclude, datetime_is_numeric)
#    9978 @final
#    9979 def describe(
#    9980     self: NDFrameT,
#    (...)
#    9984     datetime_is_numeric=False,
#    9985 ) -> NDFrameT:
#    9986     """
#    9987     Generate descriptive statistics.
#    9988
#    (...)
#   10225     max            NaN      3.0
#   10226     """
# > 10227     return describe_ndframe(
#   10228         obj=self,
#   10229         include=include,
#   10230         exclude=exclude,
#   10231         datetime_is_numeric=datetime_is_numeric,
#   10232         percentiles=percentiles,
#   10233     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\describe.py:94, in describe_ndframe(obj, include, exclude, datetime_is_numeric, percentiles)
#      86 else:
#      87     describer = DataFrameDescriber(
#      88         obj=cast("DataFrame", obj),
#      89         include=include,
#      90         exclude=exclude,
#      91         datetime_is_numeric=datetime_is_numeric,
#      92     )
# ---> 94 result = describer.describe(percentiles=percentiles)
#      95 return cast(NDFrameT, result)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\describe.py:174, in DataFrameDescriber.describe(self, percentiles)
#     172 for _, series in data.items():
#     173     describe_func = select_describe_func(series, self.datetime_is_numeric)
# --> 174     ldesc.append(describe_func(series, percentiles))
#     176 col_names = reorder_columns(ldesc)
#     177 d = concat(
#     178     [x.reindex(col_names, copy=False) for x in ldesc],
#     179     axis=1,
#     180     sort=False,
#     181 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\describe.py:241, in describe_numeric_1d(series, percentiles)
#     236 formatted_percentiles = format_percentiles(percentiles)  # type: ignore[arg-type]
#     238 stat_index = ["count", "mean", "std", "min"] + formatted_percentiles + ["max"]
#     239 d = (
#     240     [series.count(), series.mean(), series.std(), series.min()]
# --> 241     + series.quantile(percentiles).tolist()
#     242     + [series.max()]
#     243 )
#     244 return Series(d, index=stat_index, name=series.name)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\series.py:2497, in Series.quantile(self, q, interpolation)
#    2493 # We dispatch to DataFrame so that core.internals only has to worry
#    2494 #  about 2D cases.
#    2495 df = self.to_frame()
# -> 2497 result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2498 if result.ndim == 2:
#    2499     result = result.iloc[:, 0]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:10509, in DataFrame.quantile(self, q, axis, numeric_only, interpolation)
#   10506         return self._constructor([], index=q, columns=cols)
#   10507     return self._constructor_sliced([], index=cols, name=q, dtype=np.float64)
# > 10509 res = data._mgr.quantile(qs=q, axis=1, interpolation=interpolation)
#   10511 result = self._constructor(res)
#   10512 return result
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py:1451, in BlockManager.quantile(self, qs, axis, interpolation)
#    1448 new_axes = list(self.axes)
#    1449 new_axes[1] = Float64Index(qs)
# -> 1451 blocks = [
#    1452     blk.quantile(axis=axis, qs=qs, interpolation=interpolation)
#    1453     for blk in self.blocks
#    1454 ]
#    1456 return type(self)(blocks, new_axes)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py:1452, in <listcomp>(.0)
#    1448 new_axes = list(self.axes)
#    1449 new_axes[1] = Float64Index(qs)
#    1451 blocks = [
# -> 1452     blk.quantile(axis=axis, qs=qs, interpolation=interpolation)
#    1453     for blk in self.blocks
#    1454 ]
#    1456 return type(self)(blocks, new_axes)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\blocks.py:1345, in Block.quantile(self, qs, interpolation, axis)
#    1342 assert axis == 1  # only ever called this way
#    1343 assert is_list_like(qs)  # caller is responsible for this
# -> 1345 result = quantile_compat(self.values, np.asarray(qs._values), interpolation)
#    1346 # ensure_block_shape needed for cases where we start with EA and result
#    1347 #  is ndarray, e.g. IntegerArray, SparseArray
#    1348 result = ensure_block_shape(result, ndim=2)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\array_algos\quantile.py:37, in quantile_compat(values, qs, interpolation)
#      35 if isinstance(values, np.ndarray):
#      36     fill_value = na_value_for_dtype(values.dtype, compat=False)
# ---> 37     mask = isna(values)
#      38     return quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      39 else:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\missing.py:144, in isna(obj)
#      67 def isna(obj):
#      68     """
#      69     Detect missing values for an array-like object.
#      70
#    (...)
#     142     Name: 1, dtype: bool
#     143     """
# --> 144     return _isna(obj)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\missing.py:173, in _isna(obj, inf_as_na)
#     171     return False
#     172 elif isinstance(obj, (np.ndarray, ABCExtensionArray)):
# --> 173     return _isna_array(obj, inf_as_na=inf_as_na)
#     174 elif isinstance(obj, ABCIndex):
#     175     # Try to use cached isna, which also short-circuits for integer dtypes
#     176     #  and avoids materializing RangeIndex._values
#     177     if not obj._can_hold_na:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\missing.py:263, in _isna_array(values, inf_as_na)
#     261         result = ~np.isfinite(values)
#     262     else:
# --> 263         result = np.isnan(values)
#     265 return result
#
# KeyboardInterrupt:

# %%
def StartTimePlot(df):
    # drop VMs created before observation start
    df = df[df['start_time'] > 0]
    df["start_time"] = df["start_time"] // 3600
    dataset = pd.DataFrame(df.groupby(['start_time']).size().rename("count").reset_index())
    plt.figure(figsize=(10, 5))
    plt.title("Distribution of batch task create time")
    sns.lineplot(x="start_time", y="count", data=dataset)
    plt.show()

# %%
StartTimePlot(batch_task_dataframe)
# Out:
# C:\Users\hanfuqiang\AppData\Local\Temp\ipykernel_20288\1367259141.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["start_time"] = df["start_time"] // 3600
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\paper\ali\batch_desc.ipynb Cell 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/paper/ali/batch_desc.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> StartTimePlot(batch_task_dataframe)
#
# d:\paper\ali\batch_desc.ipynb Cell 13 in StartTimePlot(df)
#       <a href='vscode-notebook-cell:/d%3A/paper/ali/batch_desc.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> plt.figure(figsize=(10, 5))
#       <a href='vscode-notebook-cell:/d%3A/paper/ali/batch_desc.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a> plt.title("Distribution of batch task create time")
# ----> <a href='vscode-notebook-cell:/d%3A/paper/ali/batch_desc.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a> sns.lineplot(x="start_time", y="count", data=dataset)
#       <a href='vscode-notebook-cell:/d%3A/paper/ali/batch_desc.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a> plt.show()
#
# File d:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File d:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py:710, in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     706     return ax
#     708 p._attach(ax)
# --> 710 p.plot(ax, kwargs)
#     711 return ax
#
# File d:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py:499, in _LinePlotter.plot(self, ax, kws)
#     497         err = "estimator must be None when specifying units"
#     498         raise ValueError(err)
# --> 499     x, y, y_ci = self.aggregate(y, x, u)
#     500 else:
#     501     y_ci = None
#
# File d:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py:414, in _LinePlotter.aggregate(self, vals, grouper, units)
#     410     cis = pd.DataFrame(np.c_[est - sd, est + sd],
#     411                        index=est.index,
#     412                        columns=["low", "high"]).stack()
#     413 else:
# --> 414     cis = grouped.apply(bootstrapped_cis)
#     416 # Unpack the CIs into "wide" format for plotting
#     417 if cis.notnull().any():
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\groupby\generic.py:244, in SeriesGroupBy.apply(self, func, *args, **kwargs)
#     238 @Appender(
#     239     _apply_docs["template"].format(
#     240         input="series", examples=_apply_docs["series_examples"]
#     241     )
#     242 )
#     243 def apply(self, func, *args, **kwargs):
# --> 244     return super().apply(func, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\groupby\groupby.py:1423, in GroupBy.apply(self, func, *args, **kwargs)
#    1421 with option_context("mode.chained_assignment", None):
#    1422     try:
# -> 1423         result = self._python_apply_general(f, self._selected_obj)
#    1424     except TypeError:
#    1425         # gh-20949
#    1426         # try again, with .apply acting as a filtering
#    (...)
#    1430         # fails on *some* columns, e.g. a numeric operation
#    1431         # on a string grouper column
#    1433         with self._group_selection_context():
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\groupby\groupby.py:1469, in GroupBy._python_apply_general(self, f, data, not_indexed_same)
#    1466 if not_indexed_same is None:
#    1467     not_indexed_same = mutated or self.mutated
# -> 1469 return self._wrap_applied_output(
#    1470     data, values, not_indexed_same=not_indexed_same
#    1471 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\groupby\generic.py:398, in SeriesGroupBy._wrap_applied_output(self, data, values, not_indexed_same)
#     396     return res_ser
#     397 elif isinstance(values[0], (Series, DataFrame)):
# --> 398     return self._concat_objects(values, not_indexed_same=not_indexed_same)
#     399 else:
#     400     # GH #6265 #24880
#     401     result = self.obj._constructor(
#     402         data=values, index=self.grouper.result_index, name=self.obj.name
#     403     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\groupby\groupby.py:1058, in GroupBy._concat_objects(self, values, not_indexed_same)
#    1055     group_levels = self.grouper.levels
#    1056     group_names = self.grouper.names
# -> 1058     result = concat(
#    1059         values,
#    1060         axis=self.axis,
#    1061         keys=group_keys,
#    1062         levels=group_levels,
#    1063         names=group_names,
#    1064         sort=False,
#    1065     )
#    1066 else:
#    1067
#    1068     # GH5610, returns a MI, with the first level being a
#    1069     # range index
#    1070     keys = list(range(len(values)))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\concat.py:360, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     156 """
#     157 Concatenate pandas objects along a particular axis with optional set logic
#     158 along the other axes.
#    (...)
#     345 ValueError: Indexes have overlapping values: ['a']
#     346 """
#     347 op = _Concatenator(
#     348     objs,
#     349     axis=axis,
#    (...)
#     357     sort=sort,
#     358 )
# --> 360 return op.get_result()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\concat.py:559, in _Concatenator.get_result(self)
#     555 cons = sample._constructor
#     557 arrs = [ser._values for ser in self.objs]
# --> 559 res = concat_compat(arrs, axis=0)
#     560 result = cons(res, index=self.new_axes[0], name=name, dtype=res.dtype)
#     561 return result.__finalize__(self, method="concat")
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\concat.py:151, in concat_compat(to_concat, axis, ea_compat_axis)
#     148             to_concat = [x.astype("object") for x in to_concat]
#     149             kinds = {"o"}
# --> 151 result = np.concatenate(to_concat, axis=axis)
#     152 if "b" in kinds and result.dtype.kind in ["i", "u", "f"]:
#     153     # GH#39817
#     154     warnings.warn(
#     155         "Behavior when concatenating bool-dtype and numeric-dtype arrays is "
#     156         "deprecated; in a future version these will cast to object dtype "
#    (...)
#     160         stacklevel=find_stack_level(),
#     161     )
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
TraceLegend = "Alibaba Trace 2018"
def LifetimePlot(df):
    df=df[df["lifetime"] > 0]
    counts_lifetime = pd.DataFrame(df.groupby(['lifetime']).size().rename('Freq')).reset_index()
    counts_lifetime['cum'] = counts_lifetime['Freq'].cumsum() / counts_lifetime['Freq'].sum() * 100
    plt.figure(figsize=(10, 5))
    plt.title("batch task lifetime")
    ax = sns.lineplot(x="lifetime", y="cum",data=counts_lifetime)
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')
    ax.set_xlabel('Lifetime (Hours)')
    ax.set_ylabel('CDF')
    # zoom in
    ax.set_xlim([0,1])
    plt.show()

LifetimePlot(batch_task_dataframe)

# %%
# 
def MemoryPlot(df):
    # dataset = (df['vmmemory'].value_counts(normalize=True)*100).sort_index().T
    # result = pd.concat([dataset], axis=0)#.fillna(0)
    # ax = result.plot.bar(stacked=True, ylim=(0,100), title='VM Memory Distribution', width=0.5, align='center')
    
    dataset = pd.DataFrame(df.groupby(['plan_mem']).size().rename('count')).reset_index()
    ax = sns.barplot(x='plan_mem',y='count',data=dataset)
    ax.legend(title='Memory Size (GB)', loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=4)
    ax.set_ylabel('% of VMs')
    ax.set_xlim([0, 100])

def CorePlot(df):
    # dataset = (df['vmcorecount'].value_counts(normalize=True)*100).sort_index().T
    # result = pd.concat([dataset], axis=0)#.fillna(0)
    # ax = result.plot.bar(stacked=True, ylim=(0,100), title='VM Cores Distribution', width=0.5, align='center')
    
    dataset = pd.DataFrame(df.groupby(['plan_cpu']).size().rename('count')).reset_index()
    ax = sns.barplot(x='plan_cpu',y='count',data=dataset)
    ax.set_ylabel('% of VMs')
    ax.legend(title='Core Count', loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=5)

MemoryPlot(batch_task_dataframe)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
CorePlot(batch_task_dataframe)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def plot_correlation_map(df):
    corr = df.corr()
    _ , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    _ = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 12 }
    )

plot_correlation_map(batch_task_dataframe)
